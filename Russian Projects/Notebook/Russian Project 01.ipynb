# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
PATH = '../Data/athlete_events.csv'

# %%
df = pd.read_csv(PATH)
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df['Medal'].unique()
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
df.groupby('Sex')['Age'].min()
# Out:
# Sex
# F    11.0
# M    10.0
# Name: Age, dtype: float64

# %% [markdown]
# ***QUESTÃO 1***

# %%
##CORRETO
df[df['Year'] == 1996].groupby('Sex')['Age'].min()
# Out:
# Sex
# F    12.0
# M    14.0
# Name: Age, dtype: float64

# %% [markdown]
# ***QUESTÃO 2***

# %%
df_nondup = df.drop_duplicates(subset='Name')

# %%
print(df.shape)
print(df_nondup.shape)
# Out:
# (271116, 15)
# (134732, 15)

# %%
df_nondup['Sex'].value_counts()
# Out:
# M    100953
# F     33779
# Name: Sex, dtype: int64

# %%
df_nondup[(df['Year'] == 2000)]['Sex'].value_counts()
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# M    4240
# F    2754
# Name: Sex, dtype: int64

# %%
4240/(4240+2754)
# Out:
# 0.6062339147841006

# %%
df['Sport'].unique()
#Gymnastics
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
df_nondup[(df['Year'] == 2000) & (df_nondup['Sex'] == 'M') & (df_nondup['Sport'] == 'Gymnastics')]['Sex'].describe()
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count     62
# unique     1
# top        M
# freq      62
# Name: Sex, dtype: object

# %%
df_nondup[(df['Year'] == 2000) & (df_nondup['Sex'] == 'M')]['Sex'].describe()
# Out:
# C:\Users\Will\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count     4240
# unique       1
# top          M
# freq      4240
# Name: Sex, dtype: object

# %%
#CORRETO
62/4240
#1,5%
# Out:
# 0.014622641509433962

# %% [markdown]
# ***QUESTÃO 3***

# %%
print(df[(df['Sex'] == 'F') & (df['Sport'] == 'Basketball') & (df['Year'] == 2000)]['Height'].mean())
print(df[(df['Sex'] == 'F') & (df['Sport'] == 'Basketball') & (df['Year'] == 2000)]['Height'].std())
# Out:
# 182.38732394366198
# 9.139462087892174

# %%
##CORRETO
df[(df['Sex'] == 'F') & (df['Sport'] == 'Basketball') & (df['Year'] == 2000)]['Height'].describe()
# Out:
# count    142.000000
# mean     182.387324
# std        9.139462
# min      162.000000
# 25%      175.000000
# 50%      182.000000
# 75%      190.000000
# max      213.000000
# Name: Height, dtype: float64

# %%
df_nondup[(df_nondup['Sex'] == 'F') & (df_nondup['Sport'] == 'Basketball') & (df_nondup['Year'] == 2000)]['Height'].describe()
# Out:
# count     93.000000
# mean     181.903226
# std        9.232580
# min      162.000000
# 25%      175.000000
# 50%      182.000000
# 75%      188.000000
# max      213.000000
# Name: Height, dtype: float64

# %% [markdown]
# ***QUESTÃO 4***

# %%
##CORRETO
df[(df['Year'] == 2002) & (df['Weight'] == df[df['Year'] == 2002]['Weight'].max())]
# Out:
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %% [markdown]
# ***QUESTÃO 5***

# %%
#CORRETO
df[df['Name'] == 'Pawe Abratkiewicz']['Year'].unique()
# Out:
# array([1992, 1998, 2002], dtype=int64)

# %% [markdown]
# ***QUESTÃO 6***

# %%
#CORRETO
df[(df['Team'] == 'Australia') & (df['Year'] == 2000) & (df['Sport'] == 'Tennis')]['Medal'].value_counts()
# Out:
# Silver    2
# Name: Medal, dtype: int64

# %% [markdown]
# ***QUESTÃO 7***

# %%
#CORRETO
df[(df['Team'] == 'Switzerland') & (df['Year'] == 2016)]['Medal'].value_counts()
# Out:
# Gold      6
# Silver    3
# Bronze    2
# Name: Medal, dtype: int64

# %%
#CORRETO
df[(df['Team'] == 'Serbia') & (df['Year'] == 2016)]['Medal'].value_counts()
# Out:
# Silver    27
# Gold      14
# Bronze    13
# Name: Medal, dtype: int64

# %% [markdown]
# ***QUESTÃO 8***

# %%
df[df['Year'] == 2014]['Age'].describe()
# Out:
# count    4891.000000
# mean       25.987324
# std         4.849456
# min        15.000000
# 25%        23.000000
# 50%        26.000000
# 75%        29.000000
# max        55.000000
# Name: Age, dtype: float64

# %%
#CORRETO
_ = plt.hist(df[df['Year'] == 2014]['Age'])
plt.show()

# %% [markdown]
# ***QUESTÃO 9***

# %%
#CORRETO
df[(df['Season'] == 'Summer') & (df['City'] == 'Lake Placid')]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
#CORRETO
df[(df['Season'] == 'Winter') & (df['City'] == 'Sankt Moritz')]
# Out:
#             ID                                      Name Sex   Age  Height  \
# 935        529           Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN
# 1187       665                     Gilbert Achard-Picard   M  29.0     NaN
# 1439       802                    Tadeusz Ralf Adamowski   M  26.0   177.0
# 1454       810         Bridget Shirley Adams (-Bengough)   F  19.0     NaN
# 2707      1508                            Enrico Airoldi   M  24.0     NaN
# 2708      1509                              Remo Airoldi   M  26.0     NaN
# 5053      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5054      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5132      2921                           Fernando Alloni   M  22.0     NaN
# 5332      3022                    Pentti Johannes Alonen   M  22.0   172.0
# 5333      3022                    Pentti Johannes Alonen   M  22.0   172.0
# ...

# %% [markdown]
# ***QUESTÃO 10***

# %%
#CORRETO
df[df['Year'] == 1995]['Sport'].describe()
# Out:
# count     0
# unique    0
# Name: Sport, dtype: int64

# %%
#CORRETO
df[df['Year'] == 2016]['Sport'].describe()
# Out:
# count         13688
# unique           34
# top       Athletics
# freq           2508
# Name: Sport, dtype: object
